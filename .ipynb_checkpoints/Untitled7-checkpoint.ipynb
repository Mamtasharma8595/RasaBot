# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("grouped_sales_by_date_country_plan.xlsx")

# %%
# Convert 'PurchaseDate' to datetime if not already
df['PurchaseDate'] = pd.to_datetime(df['PurchaseDate'])

# Extract features for modeling
df['year'] = df['PurchaseDate'].dt.year
df['month'] = df['PurchaseDate'].dt.month
df['day'] = df['PurchaseDate'].dt.day

# %%
# Step 1: Extract the years from the PurchaseDate
df['year'] = df['PurchaseDate'].dt.year

# Step 2: Identify plans used in 2021, 2022, and 2023
plans_used_2021_2023 = df[df['year'].isin([2021, 2022, 2023])]['PlanName'].unique()

# Step 3: Identify plans used in 2024
plans_used_2024 = df[df['year'] == 2024]['PlanName'].unique()

# Step 4: Determine plans that were used in 2021, 2022, and 2023 but not in 2024
plans_to_remove = set(plans_used_2021_2023) - set(plans_used_2024)

# Step 5: Count the number of unique plans to remove
num_unique_plans_to_remove = len(plans_to_remove)

# Step 6: Prepare the DataFrame for plans to remove
plans_to_remove_df = pd.DataFrame(list(plans_to_remove), columns=['PlanName'])

# Step 7: Save the plans to remove in an Excel file
plans_to_remove_df.to_excel('plans_to_remove.xlsx', index=False)

# Step 8: Print results
print(f"Number of unique plans used in 2021, 2022, and 2023 but not in 2024: {num_unique_plans_to_remove}")
print("\nUnique Plan Names used in 2021, 2022, and 2023 but not in 2024:")
print(plans_to_remove)

# Step 9: Print currently used plans in 2024
print("\nCurrently used Plan Names in 2024:")
print(plans_used_2024)

# Step 10: Prepare the DataFrame for currently used plans in 2024
current_plans_2024_df = pd.DataFrame(plans_used_2024, columns=['PlanName'])

# Step 11: Save the current plans in an Excel file
current_plans_2024_df.to_excel('current_plans_2024.xlsx', index=False)
# Out:
# Number of unique plans used in 2021, 2022, and 2023 but not in 2024: 320
#
# Unique Plan Names used in 2021, 2022, and 2023 but not in 2024:
# {'Europe 20GB 30 Days', 'Switzerland Unlimited Data 30 Days', 'Greece Daily 1GB for 15 Days', 'UAE 6GB 30Days - Old', 'Portugal Daily 1GB for 10 Days', 'Europe Unlimited Data with calls 30Days', 'Italy 3GB', 'Italy Daily 1GB for 30 Days', 'France Daily 1GB for 15 Days', 'UK 6GB 10 Days', 'Europe 25GB 1 Year', 'India 6GB 10Days', 'Europe 5GB 30 Days', 'Iceland 5GB Data 30 Days', 'Taiwan 30GB 30 Days', 'Germany 10GB 30 days Roamability', 'Spain 100GB 180 Days', 'Guam Unlimited 4 Days', 'UK 20GB 15 Days', 'Airhub Taiwan 1 GB 7 Days', 'Europe 25GB Monthly', 'USA 3GB Data with Calls 30Days', 'Denmark 25GB 30Days', 'Italy 1GB 7 days Roambility', 'Macedonia 5Gb 10Days stockin', 'Airhub Germany 5 GB Roamability', 'Canada 1 GB 7 Days', 'Russia Daily 1GB for 30 Days', 'Test 1 MB Uk', 'Taiwan Daily 1GB for 10 Days', 'Switzerland 30GB Monthly', 'USA 12GB Data with Calls 30Days', 'Middle East Daily 1GB for 7 Days', 'Philippines Daily 1GB for 8 Days', 'Turkey 200GB 365 Days', 'USA 10GB Data with Calls Monthly', 'U
B for 5 Days', 'Suriname 5GB 10Days', 'Italy 1GB 7 Days', 'Middle East 5GB 15 Days', 'USA 6GB 30Days duplicate (Delete)', 'Japan Unlimited 5 Days', 'USA 6GB Monthly Delete', 'UK 20GB 10 Days', 'USA Unlimited voice and Text 30 Days', 'Switzerland High Speed premium data plan with voice', 'Laos 5GB 30 Days- del', 'Singapore 15GB 30 Days', 'Grenada 5GB 10Days', 'United States Daily 1GB for 5 Days', 'Malta 5GB 30 Days', 'Italy Daily 1GB for ...
#
# Currently used Plan Names in 2024:
# ['UK 250GB 30Days' 'UK 100GB 30 Days' 'UAE 3GB 30 Days-OLD DELETE'
#  'UAE 10GB 30Days' 'Sri Lanka 3GB 30 Days'
#  'Thailand Unlimited 15Days - DTC old'
#  'Thailand 50GB 30 Days - delete - QC' 'Thailand 30GB 30Days'
#  'Sri Lanka 5GB 30 Days' 'UK 750GB 30 Days - ABZ - Delete'
#  'Trinidad and Tobago 25GB 30Days - old'
#  'USA Unlimited Data with Calls 10Days' 'Asia 5GB Data'
#  'USA Unlimited Data with Calls 30 Days - Premium'
#  'USA Unlimited Data with Calls 5Days' 'United States 15GB Data 30 days'
#  'United States 5GB Data 30 days' 'United states 3GB Data 30 Days'
#  'Europe 40GB Data with Calls 15Days' 'Europe Unlimited 30Days - Old'
#  'Global 25GB 30Days - old' 'Global 3GB Data 15 days'
#  'Latin America 200GB 30Days' 'North America Unlimited 30Days'
#  'Spain 10GB 30 Days' 'USA Unlimited Data with Calls 15Days'
#  'St Vincent and Grenadines 25GB 30Days - oLd' 'Portugal 5GB 30 Days'
#  'Russia 10GB 30 Days' 'St Lucia 30GB Data with Calls 30Days'
#  'Aruba 25GB 30Days - Old' 'Australia 25GB 30Days - Old'
#  'Barbados 25GB 30Days - Old' 'Brazil 12GB Data 30Days'
#  'Brazil 12GB Data with calls 30Days' 'Brazil 20GB Data with calls 30Days'
#  'Brazil 42GB Data with calls 30Days' 'Brazil 4GB Data with calls 30Days'
#  'British Virgin Islands 25GB 30Days - old'
#  'Canada 30GB Data with calls 30Days' 'Cayman Islands 25GB 30Days - Old'
#  'China 10GB 30 Days - old QC_RX'
#  'Antigua and Barbuda 30GB Data with Calls 30Days' 'Egypt 5Gb 10Days'
#  'France 10GB 30 Days' 'France 40GB Data with Calls 15Days'
#  'France 5GB 30 Days' 'France Unlimited 10Days'
#  'Jamaica 25GB 30Days - Old' 'Japan 20GB 30 Days  - Tel25'
#  'Japan Test plan Donot buy' 'Kenya 25GB 30Days - Old'
#  'Mexico 25GB 30Days - Old' 'Mexico 5GB 30Days' 'China 5 GB 30 Days'
#  'UAE 5GB 30Days-OLD DELETE' 'Turkey 5GB 15Days'
#  'Switzerland Unlimited Data 10Days' 'Thailand 60GB 10Days - DTC old'
#  'Thailand 15GB 30Days - delete- QC' 'UK 3GB 30Days'
#  'Thailand Unlimited 10Days - DTC old' 'UK 6GB 30 Days'
#  'USA 3GB Data with Calls 15Days' 'United States 10GB Data 30 days'
#  'South Korea Unlimited 5 Days' 'Romania Unlimited Data 15Days'
#  'Greece Unlimited Data 15Days' 'Albania 2GB 7Days'
#  'South Korea 30GB 30Days' 'United Sates 500MB 7Days' 'Asia 3GB 30Days'
#  'Faroe Islands 10GB 30Days' 'Algeria 2GB 7Days' 'Asia 50GB 30Days'
#  'South Korea Unlimited 10 Days' 'Sweden 50GB Data with Calls 30Days'
#  'Iceland 50GB Data with Calls 30Days' 'Mauritius 2GB 7Days'
#  'Asia 30GB 30Days' 'Azerbaijan 2GB 7Days' 'Kazakhstan 2GB 7Days'
#  'Iraq 5GB 10Days' 'Kosovo 30GB Data with Calls 30Days'
#  'Eurasia 3GB 30Days' 'Spain Unlimited Data with Calls 15Days'
#  'Egypt 15GB 30Days' 'Australia Unlimited Data with calls 7Days'
#  'Anguilla 30GB Data with Calls 30Days' 'Sweden Unlimited Data 15Days'
#  'Philippines 5GB 30Days' 'Norway 50GB Data with Calls 30Days'
#  'Malta 2GB 7Days' 'Peru 10GB Data with calls 30Days'
#  'Saint Martin 50GB Data with Calls 30Days' 'Denmark 2GB 7Days'
#  'Guernsey 50GB Data with Calls 30Days'
#  'Greece 50GB Data with Calls 30Days' 'Latin America 3GB 30Days'
#  'Egypt 20GB 30Days' 'Belarus 10GB 30days' 'Greece 2GB 7Days'
#  'Sweden 3GB 30Days' 'Latin America 5GB 30Days' 'Lithuania 10GB 30Days'
#  'Latin America 10GB 30Days'
#  'Global 25GB with calls Per Month for 180 Days' 'Malaysia 1GB 30Days'
#  'Ireland Unlimited Data with Calls Monthly' 'Kosovo 2GB 7Days'
#  'USA Unlimited Tablet only plan 30Days'
#  'Bulgaria 50GB Data with Calls 30Days' 'Bulgaria 2GB 7Days'
#  'Serbia 2GB 7Days' 'Malaysia 500MB 30Days'
#  'Ireland 50GB Data with Calls 30Days' 'Kosovo 3GB 30days'
#  'Slovenia 2GB 7Days' 'Slovenia 10GB 30 Days' 'Norway 2GB 7Days'
#  'Israel 2GB 7Days' 'Latin America 1GB 7Days' 'Andorra 2GB 7Days'
#  'Albania 30GB Data with Calls 30Days' 'UAE 1MB 1Day' 'Tunisia 2GB 7Days'
#  'UAE 500MB 30Days' 'Global Free esim 100MB'
#  'Europe 65GB Data with Calls 30Days'
#  'USA Premium Unlimited Data with Calls Monthly'
#  'United States Daily 1GB for 15 Days' 'Kuwait 2GB 7Days'
#  'Sweden 2GB 7Days' 'Caribbean 5GB 30days' 'Algeria 3GB 30days'
#  'Iran 10GB 30days' 'Caribbean 3GB 30days' 'Caribbean 15GB 30days'
#  'Portugal 2GB 7Days' 'Morocco 3GB 30Days' 'Caribbean 10GB 30days'
#  'Jordan 2GB 7Days' 'Hungary 2GB 7Days' 'Thailand 500MB 30Days'
#  'Ukraine 2GB 7Days' 'Romania Unlimited Data 10Days' 'Telco Blank stocks'
#  'Kyrgyzstan 10GB 15Days' 'Hungary Unlimited 10Days'
#  'Australia 1GB 30Days' 'Monaco 15GB 30days'
#  'UK Unlimited Data with calls 90Days' 'Costa Rica 3GB 30Days'
#  'Ecuador 5GB 30Days' 'El Salvador 5GB 30Days' 'Europe 3GB 30Days'
#  'Ireland 5GB 30Days' 'Honduras 3GB 30Days' 'Europe Unlimited Data 30Days'
#  'Europe Unlimited Data 15Days' 'Philippines 500MB 30Days'
#  'Colombia 5GB 30Days' 'Belarus 2GB 7Days' 'Azerbaijan 3GB 30days'
#  'Saint Lucia 3GB 30Days' 'Jordan 5GB 30Days' 'Nigeria 15GB 30Days'
#  'British Virgin Islands 10GB 30Days' 'Egypt 1 MB test'
#  'Montenegro 5GB 30Days' 'Netherlands 50GB Data with Calls 30Days'
#  'Turks and Caicos Islands 3GB 30Days' 'Azerbaijan 10GB 30days'
#  'Azerbaijan 15GB 30days' 'Iran 2GB 7Days' 'Ireland 15GB 30Days'
#  'Hong Kong 3GB 30Days' 'Mayotte 50GB Data with Calls 30Days'
#  'Montenegro 10GB 30Days' 'New Zealand 2GB 7Days' 'UK 1GB 30Days'
#  'Ireland 10GB 30Days' 'Spain 6GB Data with calls 30Days'
#  'Turkey 15GB Data with calls 30Days' 'Iceland 5GB 30Days'
#  'Gabon 3GB 30days' 'Poland 50GB Data with Calls 30Days'
#  'Macedonia 5GB 30Days' 'Turkey 6GB Data with calls 30Days'
#  'Costa Rica 10GB 30Days' 'Antigua and Barbuda 5GB 30Days'
#  'Italy 15GB Data with calls 30Days' 'Iceland 10GB 30Days'
#  'Saint Vincent and Grenadines 3GB 30Days' 'Montenegro 15GB 30Days'
#  'Jersey 3GB 30Days' 'Turks and Caicos Islands 10GB 30Days'
#  'China Unlimited 2Days' 'Guatemala 5GB 30Days' 'Jersey 10GB 30Days'
#  'Curacao 10GB 30Days' 'Ghana 2GB 7Days' 'Iceland 15GB 30Days'
#  'Grenada 3GB 30Days' 'Singapore Unlimited 2Days' 'Croatia 2GB 7Days'
#  'Belarus 3GB 30days' 'South Korea Unlimited 2Days'
#  'Central America 10GB 30days' 'El Salvador 10GB 30Days'
#  'Cambodia 30GB 30Days' 'Hong Kong 15GB 30Days'
#  'Romania 50GB Data with Calls 30Days' 'Nigeria 5GB 30Days'
#  'Peru 10GB 30Days' 'Turkey Unlimited Data 5Days'
#  'Saudi Arabia 15GB 30 Days' 'Macedonia 3GB 30Days'
#  'British Virgin Islands 3GB 30Days' 'Grenada 30GB Data with Calls 30Days'
#  'Grenada 10GB 30Days' 'Jordan 8GB 30 Days' 'Latvia 15GB 30Days'
#  'Taiwan Unlimited 2Days' 'Greece 15GB Data with calls 30Days'
#  'Hawaii 5GB Data 30 Days' 'Italy 6GB Data with calls 30Days'
#  'Iceland 3GB 30Days' 'Ghana 3GB 30days' 'Saint Lucia 10GB 30Days'
#  'Japan Unlimited 4Days' 'Sri Lanka Daily 1GB for 5 Days'
#  'Belgium 5GB 30Days' 'Hawaii 10GB Data 30 Days' 'Oman 10GB 30Days'
#  'Montenegro 3GB 30Days' 'Curacao 3GB 30Days'
#  'Europe 50GB Data with Calls 30Days - Old'
#  "Europe Unlimited 30Days - old simcredible don't use"
#  'Turkey Unlimited Data 3Days' 'China 4GB 30 Days' 'Curacao 5GB 30Days'
#  'Europe 300GB 5G Internet Data 30Days'
#  'Europe 300GB 5G Internet Data 15Days' 'Thailand 1GB 30Days'
#  "Italy 50GB Data with Calls 30Days - old simcredible don't use"
#  'Turkey Unlimited Data 30Days' 'Guatemala 10GB 30Days'
#  "Germany 50GB Data with Calls 30Days - old simcredible don't use"
#  'British Virgin Islands 5GB 30Days'
#  "Greece 50GB Data with Calls 30Days - old simcredible don't use"
#  'Hawaii 3GB Data 30 Days' 'Greece 6GB Data with calls 30Days'
#  'Macao 3GB 30Days' 'Thailand Unlimited 7Days'
#  'Trinidad and Tobago 5GB 30Days' 'Pakistan 5GB 30 Days'
#  'Gibraltar 3GB 30Days' 'Pakistan 10GB 30 Days' 'Nepal 10GB 30 Days'
#  'Madagascar 10GB 30 Days' 'Cyprus 10GB 30 Days' 'Lithuania 3GB 30Days'
#  'Jamaica 10GB 30Days' 'Nepal 5GB 30 Days' 'Netherlands 2GB 7Days'
#  'Lithuania 15GB 30Days' 'Sweden Unlimited Data 10Days'
#  'Kosovo 5GB 30days' 'Thailand 60GB 10Days' 'Grenada 5GB 30Days'
#  'Jordan 10GB 30Days' 'Bangladesh 3GB 30 Days'
#  'Poland Unlimited Data 15Days' 'Armenia 10GB 30 Days'
#  'Thailand 300GB 7Days' 'Madagascar 5GB 30 Days' 'Turkey 300GB 15Days'
#  'Finland 2GB 7Days' 'Malawi 5GB 30 Days' 'UK 100GB 30Days - OLD'
#  'Armenia 5GB 30 Days' 'New Zealand 5GB 30Days'
#  'Spain 15GB Data with calls 30Days' 'Thailand 300GB 5Days'
#  'China 10GB 30 Days' 'Malawi 3GB 30 Days' 'Uzbekistan 10GB 30 Days'
#  'Uganda 5GB 30 Days' 'Serbia 15GB Data with calls 30Days'
#  'Uzbekistan 3GB 30 Days' 'Cyprus 3GB 30 Days'
#  'Albania 15GB Data with calls 30Days' 'Malawi 10GB 30 Days'
#  'Nepal 3GB 30 Days' 'Switzerland 6GB Data with calls 30Days'
#  'Turkey 300GB 30Days' 'Albania 6GB Data with calls 30Days'
#  'Bangladesh 10GB 30 Days' 'Sweden 15GB Data with calls 30Days'
#  'Macedonia 6GB Data with calls 30Days' 'Antigua and Barbuda 10GB 30Days'
#  'Armenia 3GB 30 Days' 'Canada 25GB Data With Calls 30Days'
#  'New Zealand 3GB 30Days' 'Uganda 10GB 30 Days' 'Anguilla 10GB 30Days']

# %%
import re
import pandas as pd

# Month mapping (ensure this exists)
months_reverse = {
    "january": "01",
    "february": "02",
    "march": "03",
    "april": "04",
    "may": "05",
    "june": "06",
    "july": "07",
    "august": "08",
    "september": "09",
    "october": "10",
    "november": "11",
    "december": "12"
}

def extract_specific_date(text):
    # Regex pattern for extracting a specific date like "5 April 2024"
    date_pattern = r'\b(\d{1,2})\s*(January|February|March|April|May|June|July|August|September|October|November|December)\s*(\d{4})\b'
    match = re.search(date_pattern, text, re.IGNORECASE)
    
    if match:
        day, month_name, year = match.groups()
        month = months_reverse[month_name.lower()]  # Get the numeric month from the name
        specific_date = pd.to_datetime(f"{year}-{month}-{day}", format="%Y-%m-%d")  # Convert to datetime object
        return specific_date.date()  # Return only the date part (not time)
    
    return None

# Test the function
user_input = "Please provide sales data for 5 April 2024"
specific_date = extract_specific_date(user_input)

if specific_date:
    print(f"Extracted Date: {specific_date}")
else:
    print("No date found.")
# Out:
# Extracted Date: 2024-04-05

# %%
import re
import pandas as pd

# Month mapping
months_reverse = {
    "january": "01",
    "february": "02",
    "march": "03",
    "april": "04",
    "may": "05",
    "june": "06",
    "july": "07",
    "august": "08",
    "september": "09",
    "october": "10",
    "november": "11",
    "december": "12"
}

# Function to extract specific date
def extract_specific_date(user_message):
    # Regex pattern for extracting a specific date like "5 April 2024"
    date_pattern = r'\b(\d{1,2})\s*(January|February|March|April|May|June|July|August|September|October|November|December)\s*(\d{4})\b'
    match = re.search(date_pattern, user_message, re.IGNORECASE)
    
    if match:
        day, month_name, year = match.groups()
        month = months_reverse[month_name.lower()]  # Get the numeric month from the name
        specific_date = pd.to_datetime(f"{year}-{month}-{day}", format="%Y-%m-%d")  # Convert to datetime object
        return specific_date.date()  # Return only the date part (not time)
    
    return None

# Example of extracting date from a user message
user_message = "Can you give me the sales data for 15 August 2023?"

# Extract date from the message
specific_date = extract_specific_date(user_message)

if specific_date:
    print(f"Extracted Date: {specific_date}")
else:
    print("No valid date found in the message.")
# Out:
# Extracted Date: 2023-08-15

# %%
import re
import pandas as pd

# Mapping for month names to numeric format
months_reverse = {
    "january": "01",
    "february": "02",
    "march": "03",
    "april": "04",
    "may": "05",
    "june": "06",
    "july": "07",
    "august": "08",
    "september": "09",
    "october": "10",
    "november": "11",
    "december": "12"
}

def extract_date_range(text):
    # Regex pattern for extracting a date range like "from 2 April 2023 to 30 June 2024"
    range_pattern = r'from\s+(\d{1,2})\s*(January|February|March|April|May|June|July|August|September|October|November|December)\s*(\d{4})\s+to\s+(\d{1,2})\s*(January|February|March|April|May|June|July|August|September|October|November|December)\s*(\d{4})'
    
    match = re.search(range_pattern, text, re.IGNORECASE)
    if match:
        start_day, start_month_name, start_year, end_day, end_month_name, end_year = match.groups()
        
        # Get numeric month from the month name
        start_month = months_reverse[start_month_name.lower()]
        end_month = months_reverse[end_month_name.lower()]

        # Convert to datetime objects
        start_date = pd.to_datetime(f"{start_year}-{start_month}-{start_day}", format="%Y-%m-%d")
        end_date = pd.to_datetime(f"{end_year}-{end_month}-{end_day}", format="%Y-%m-%d")

        return start_date.date(), end_date.date()

    return None

# Example usage: extract date range from user message
user_message = "Show me the sales from 5 April 2023 to 30 June 2024"
date_range = extract_date_range(user_message)

if date_range:
    start_date, end_date = date_range
    print(f"Extracted Start Date: {start_date}")
    print(f"Extracted End Date: {end_date}")
else:
    print("No valid date range found in the message.")
# Out:
# Extracted Start Date: 2023-04-05
# Extracted End Date: 2024-06-30
